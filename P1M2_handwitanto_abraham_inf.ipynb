# %%
#import libraries
import pandas as pd
import pickle
import os

# %%
deployment_folder = 'C:/Users/handw/Documents/FTDS/p1-ftds036-rmt-m2-ebhon/deployment'

#Load file yang sudah di save sebelumnya
with open(os.path.join(deployment_folder, 'pipeline.pkl'), 'rb') as file_1:
    best_result_rs = pickle.load(file_1)

# %%
best_result_rs
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['usia', 'jam_kerja']),
#                                                  ('high_car', TargetEncoder(),
#                                                   ['negara_asal', 'pendidikan',
#                                                    'pekerjaan']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['jenis_pekerjaan',
#                                                    'status_perkawinan',
#                                                    'hubungan', 'ras',
#                                                    'jenis_kelamin'])])),
#                 ('smote',
#                  SMOTENC(categorical_features=[9, 2, 4, 1, 3, 5, 6, 7],
#                          random_state=42)),
# ...

# %%
data = {
    'usia': 35,
    'jenis_pekerjaan': ['Pemerintah Pusat'],
    'bobot_sampel': [1],
    'pendidikan': ['Sarjana'],
    'angka_pendidikan': [4],
    'status_perkawinan': ['Menikah'],
    'pekerjaan': ['Administrasi/Klerikal'],
    'hubungan': ['Suami'],
    'ras': ['Asian-Pac-Islander'],
    'jenis_kelamin': ['Perempuan'],
    'keuntungan_modal': [2000],
    'kerugian_modal':[0],
    'jam_kerja': [40],
    'negara_asal': ['United-States'],
}

df = pd.DataFrame(data)
df
# Out:
#    usia   jenis_pekerjaan  bobot_sampel pendidikan  angka_pendidikan  \
# 0    35  Pemerintah Pusat             1    Sarjana                 4
#
#   status_perkawinan              pekerjaan hubungan                 ras  \
# 0           Menikah  Administrasi/Klerikal    Suami  Asian-Pac-Islander
#
#   jenis_kelamin  keuntungan_modal  kerugian_modal  jam_kerja    negara_asal
# 0     Perempuan              2000               0         40  United-States

# %%
high_car = ['negara_asal','pendidikan','pekerjaan']
num_cols = ['usia','jam_kerja']
cat_cols = ['jenis_pekerjaan','status_perkawinan','hubungan','ras','jenis_kelamin']

all_cat_cols = high_car + cat_cols

categorical_indices = [df.columns.get_loc(col) for col in all_cat_cols]

# %%
for index, row in df.iterrows():
    pred = best_result_rs.predict(df)
    if (int(pred[index] == 0)):
        hasil = "<= 50.000.000 IDR"
    else:
        hasil = "> 50.000.000 IDR"

    print (f"Hasil analisa untuk data ke {index+1}, pendapatan ybs adalah {hasil}")
# Out:
# Hasil analisa untuk data ke 1, pendapatan ybs adalah > 50.000.000 IDR
